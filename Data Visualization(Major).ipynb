# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('spgclasstry.csv')

# %%
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_cloud_cover_sfc  \
# 0                       1035.0                    0.0
# 1                       1035.1                    0.0
# 2                       1035.4                    0.0
# 3                       1035.4                    0.0
# 4                       1034.4                    0.0
#
#    medium_cloud_cover_mid_cld_lay  low_cloud_cover_low_cld_lay  \
# 0                               0                            0
# 1                               0                            0
# 2                               0                            0
# ...

# %%
plt.scatter(df['temperature_2_m_above_gnd'],df['Classification'])
plt.title('temperature_2_m_above_gnd VS Category of output')
plt.xlabel('temperature_2_m_above_gnd')
plt.ylabel('classification')
plt.show()

# %%
plt.scatter(df['relative_humidity_2_m_above_gnd'],df['Classification'])
plt.title('relative_humidity_2_m_above_gnd VS Category of output')
plt.xlabel('relative_humidity_2_m_above_gnd')
plt.ylabel('Classification')
plt.show()

# %%
plt.scatter(df['mean_sea_level_pressure_MSL'],df['Classification'])
plt.title('mean_sea_level_pressure_MSL VS Category of output')
plt.xlabel('mean_sea_level_pressure_MSL')
plt.ylabel('Classification')
plt.show()

# %%
plt.scatter(df['wind_speed_10_m_above_gnd'],df['Classification'])
plt.title('wind_speed_10_m_above_gnd VS Category of output')
plt.xlabel('wind_speed_10_m_above_gnd')
plt.ylabel('Classification')
plt.show()

# %%
plt.scatter(df['angle_of_incidence'],df['Classification'])
plt.title('angle_of_incidence VS Category of output')
plt.xlabel('angle_of_incidence')
plt.ylabel('Classification')
plt.show()

# %%
plt.scatter(df['zenith'],df['Classification'])
plt.title('zenith VS Category of output')
plt.xlabel('zenith')
plt.ylabel('classification')
plt.show()

# %%
plt.scatter(df['azimuth'],df['Classification'])
plt.title('azimuth VS Category of output')
plt.xlabel('azimuth')
plt.ylabel('classification')
plt.show()

# %%
plt.scatter(df['total_cloud_cover_sfc'],df['Classification'])
plt.title('total_cloud_cover_sfc VS Category of output')
plt.xlabel('total_cloud_cover_sfc')
plt.ylabel('Classification')
plt.show()

# %%
df.columns
# Out:
# Index(['temperature_2_m_above_gnd', 'relative_humidity_2_m_above_gnd',
#        'mean_sea_level_pressure_MSL', 'total_precipitation_sfc',
#        'snowfall_amount_sfc', 'total_cloud_cover_sfc',
#        'high_cloud_cover_high_cld_lay', 'medium_cloud_cover_mid_cld_lay',
#        'low_cloud_cover_low_cld_lay', 'shortwave_radiation_backwards_sfc',
#        'wind_speed_10_m_above_gnd', 'wind_direction_10_m_above_gnd',
#        'wind_speed_80_m_above_gnd', 'wind_direction_80_m_above_gnd',
#        'wind_speed_900_mb', 'wind_direction_900_mb',
#        'wind_gust_10_m_above_gnd', 'angle_of_incidence', 'zenith', 'azimuth',
#        'generated_power_kw'],
#       dtype='object')
